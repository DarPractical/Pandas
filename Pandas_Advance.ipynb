# %% [markdown]
# # Q1. List any five functions of the pandas library with execution.

# %%
import pandas as pd
df=pd.read_csv('analysis-public-place-assaults-sexual-assaults-and-robberies-2015-csv.csv',index_col=None)
df.columns
# Out:
# Index(['Index', 'Area_unit_2013_code', 'Area_unit_2013_label',
#        'Victimisations_calendar_year_2015', 'Population_mid_point_2015',
#        ' Rate_per_10000_population ', ' Rate_ratio_NZ_average_rate ',
#        'Urban_area_2013_code', 'Urban_area_2013_label', 'Urban_area_type',
#        'Territorial_authority_area_2013_code',
#        'Territorial_authority_area_2013_label', 'Region_2013_code',
#        'Region_2013_label'],
#       dtype='object')

# %%
df.set_index("Region_2013_label")
# Out:
#                       Index  Area_unit_2013_code  \
# Region_2013_label
# Auckland Region           1               514102
# Wellington Region         2               573101
# Waikato Region            3               529700
# Auckland Region           4               514103
# Canterbury Region         5               591500
# ...                     ...                  ...
# Auckland Region        2016               506653
# Southland Region       2017               610601
# Bay of Plenty Region   2018               536513
# Wellington Region      2019               574302
# Waikato Region         2020               527007
#
#                                  Area_unit_2013_label  \
# Region_2013_label
# Auckland Region                 Auckland Central West
# Wellington Region     Willis Street-Cambridge Terrace
# Waikato Region                       Hamilton Central
# Auckland Region                 Auckland Central East
# Canterbury Region                    Cathedral Square
# ...

# %%
df[(df['Population_mid_point_2015']>500) & (df['Victimisations_calendar_year_2015']>300)]
# Out:
#    Index  Area_unit_2013_code             Area_unit_2013_label  \
# 0      1               514102            Auckland Central West
# 1      2               573101  Willis Street-Cambridge Terrace
# 2      3               529700                 Hamilton Central
# 3      4               514103            Auckland Central East
# 4      5               591500                 Cathedral Square
#
#    Victimisations_calendar_year_2015  Population_mid_point_2015  \
# 0                                550                      15900
# 1                                447                       8300
# 2                                380                       3170
# 3                                375                      13250
# 4                                305                        570
#
#    Rate_per_10000_population   Rate_ratio_NZ_average_rate   \
# 0                         346                          6.6
# 1                         539                         10.3
# ...

# %%
df[df["Area_unit_2013_label"]=="Hamilton Central"]
# Out:
#    Index  Area_unit_2013_code Area_unit_2013_label  \
# 2      3               529700     Hamilton Central
#
#    Victimisations_calendar_year_2015  Population_mid_point_2015  \
# 2                                380                       3170
#
#    Rate_per_10000_population   Rate_ratio_NZ_average_rate   \
# 2                       1,199                         22.9
#
#    Urban_area_2013_code Urban_area_2013_label  Urban_area_type  \
# 2                     6         Hamilton Zone  Main urban area
#
#    Territorial_authority_area_2013_code Territorial_authority_area_2013_label  \
# 2                                    16                         Hamilton City
#
#    Region_2013_code Region_2013_label
# 2                 3    Waikato Region

# %%
df["Victimisations_calendar_year_2015"].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0       550
# 1       447
# 2       380
# 3       375
# 4       305
#        ...
# 2015      0
# 2016      0
# 2017      0
# 2018      0
# 2019      0
# Name: Victimisations_calendar_year_2015, Length: 2020, dtype: int64>

# %%
import pandas as pd
df=pd.read_csv("ds_salaries.csv")

# %%
df.columns
# Out:
# Index(['work_year', 'experience_level', 'employment_type', 'job_title',
#        'salary', 'salary_currency', 'salary_in_usd', 'employee_residence',
#        'remote_ratio', 'company_location', 'company_size'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3755, step=1)

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=3755, step=1),
#  Index(['work_year', 'experience_level', 'employment_type', 'job_title',
#         'salary', 'salary_currency', 'salary_in_usd', 'employee_residence',
#         'remote_ratio', 'company_location', 'company_size'],
#        dtype='object')]

# %%
df.ndim
# Out:
# 2

# %%
df.values[0][7]
# Out:
# 'ES'

# %%
df.columns
# Out:
# Index(['work_year', 'experience_level', 'employment_type', 'job_title',
#        'salary', 'salary_currency', 'salary_in_usd', 'employee_residence',
#        'remote_ratio', 'company_location', 'company_size'],
#       dtype='object')

# %%
sal=df["salary"]

# %%
max(sal)
# Out:
# 30400000

# %%
df[df["salary"]==30400000]
# Out:
#       work_year experience_level employment_type       job_title    salary  \
# 3669       2021               MI              FT  Data Scientist  30400000
#
#      salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 3669             CLP          40038                 CL           100
#
#      company_location company_size
# 3669               CL            L

# %%
df["salary"]>1200000
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3750    False
# 3751    False
# 3752    False
# 3753    False
# 3754     True
# Name: salary, Length: 3755, dtype: bool

# %%
df[df["salary"]>1200000]
# Out:
#       work_year experience_level employment_type  \
# 41         2022               MI              FT
# 156        2023               MI              FT
# 217        2023               EN              FT
# 528        2023               SE              FT
# 735        2023               MI              FT
# 738        2023               MI              FT
# 988        2023               SE              FT
# 1260       2023               MI              FT
# 1462       2023               MI              FT
# 1549       2023               MI              FT
# 1596       2022               MI              FT
# 1738       2021               SE              FT
# 1739       2022               MI              FT
# 1868       2022               SE              FT
# 1918       2022               MI              FT
# 1946       2022               MI              FT
# 2032       2021               MI              FT
# 2358       2022               EN              FT
# ...

# %%
sal.median
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.median of 0         80000
# 1         30000
# 2         25500
# 3        175000
# 4        120000
#          ...
# 3750     412000
# 3751     151000
# 3752     105000
# 3753     100000
# 3754    7000000
# Name: salary, Length: 3755, dtype: int64>

# %%
df.mean
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.mean of       work_year experience_level employment_type                 job_title  \
# 0          2023               SE              FT  Principal Data Scientist
# 1          2023               MI              CT               ML Engineer
# 2          2023               MI              CT               ML Engineer
# 3          2023               SE              FT            Data Scientist
# 4          2023               SE              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
#
# ...

# %%
df.median
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.median of       work_year experience_level employment_type                 job_title  \
# 0          2023               SE              FT  Principal Data Scientist
# 1          2023               MI              CT               ML Engineer
# 2          2023               MI              CT               ML Engineer
# 3          2023               SE              FT            Data Scientist
# 4          2023               SE              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
#
# ...

# %%
df.columns
# Out:
# Index(['work_year', 'experience_level', 'employment_type', 'job_title',
#        'salary', 'salary_currency', 'salary_in_usd', 'employee_residence',
#        'remote_ratio', 'company_location', 'company_size'],
#       dtype='object')

# %%
df[['job_title','salary']].head(10)
# Out:
#                   job_title  salary
# 0  Principal Data Scientist   80000
# 1               ML Engineer   30000
# 2               ML Engineer   25500
# 3            Data Scientist  175000
# 4            Data Scientist  120000
# 5         Applied Scientist  222200
# 6         Applied Scientist  136000
# 7            Data Scientist  219000
# 8            Data Scientist  141000
# 9            Data Scientist  147100

# %%
g=df.groupby("job_title")

# %%
g=list(g)
g
# Out:
# [('3D Computer Vision Researcher',
#         work_year experience_level employment_type  \
#   2022       2022               SE              FT
#   2149       2021               EN              FT
#   2206       2022               EN              FT
#   3537       2021               MI              PT
#
#                             job_title  salary salary_currency  salary_in_usd  \
#   2022  3D Computer Vision Researcher   10000             USD          10000
#   2149  3D Computer Vision Researcher   20000             USD          20000
#   2206  3D Computer Vision Researcher   50000             USD          50000
#   3537  3D Computer Vision Researcher  400000             INR           5409
#
#        employee_residence  remote_ratio company_location company_size
#   2022                 CA            50               AL            S
#   2149                 AS             0               AS            M
#   2206                 US           100               CR            S
# ...

# %% [markdown]
# df

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
def finding_rotation(list_of_num):
    pass

# %% [markdown]
# `All numbers should be uni=[9,8,7,6,5,4,3,2,1]`
# No elements in list=[]
# one element in list=[1]
# no roation wallah=[9,8,7,6,5,4,3,2,1] should return No roation
# just once roated=[1,9,8,7,6,5,4,3,2]
# n-1 times roated=[1,2,3,4,5,6,7,8,9]

# %%
def count_roat(nums):
    sorted_nums=nums.sort(reverse=True)
    if sorted_nums==nums:
        return 'A list That was Not rotated'
    elif len(nums)==1:
        return 'A list contains only one element'
    elif len(nums)==0:
        return 'A list has Zero Elements'

    while True:
        first_ele=nums[0]
        for count in range(len(nums)):
            nums.remove(first_ele)
            nums.insert(-1,first_ele)

            if nums==sorted_nums:
                return count
            else:
                return 'see carefully'


nums=[9,8,7,1,2,3,4,5,6]
count_roat(nums) 
    
# def checking_roat(nums,count_roat()):

# %%
class TreeNode:
    def __init__(self,key):
        self.key=key
        self.left=None
        self.right=None

Node0=TreeNode(2)

Node1=TreeNode(3)

Node2=TreeNode(5)


#nodes for Main
Node0.left=Node1
Node0.right=Node2


#nodes for node2
Node2_r=TreeNode(7)
Node2_l=TreeNode(3)
Node2.left=Node2_l
Node2.right=Node2_r

#Nodes for Node 1
Node1_l=TreeNode(1)
Node1.left=Node1_l

# NOdes for Node2_r
Node2_r_r=TreeNode(8)
Node2_l_l=TreeNode(6)
Node2_r.right=Node2_r_r
Node2_r.left=Node2_l_l


# NOdes for Node2_l
Node2_l_r=TreeNode(4)

Node2_l.right=Node2_l_r

Node0.right.left.right.key
# Out:
# 4

# %%
import pandas as pd
df=pd.read_csv('analysis-public-place-assaults-sexual-assaults-and-robberies-2015-csv.csv')print
# Out:
# 60

# %%
print(df.to_string())
# Out:
#       Index  Area_unit_2013_code                Area_unit_2013_label  Victimisations_calendar_year_2015  Population_mid_point_2015  Rate_per_10000_population   Rate_ratio_NZ_average_rate   Urban_area_2013_code                Urban_area_2013_label       Urban_area_type  Territorial_authority_area_2013_code Territorial_authority_area_2013_label  Region_2013_code         Region_2013_label
# 0         1               514102               Auckland Central West                                550                      15900                         346                          6.6                     4                Central Auckland Zone       Main urban area                                    76                              Auckland                 2           Auckland Region
# ...

# %%
df.info()=='int64'
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2020 entries, 0 to 2019
# Data columns (total 14 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Index                                  2020 non-null   int64
#  1   Area_unit_2013_code                    2020 non-null   int64
#  2   Area_unit_2013_label                   2020 non-null   object
#  3   Victimisations_calendar_year_2015      2020 non-null   int64
#  4   Population_mid_point_2015              2020 non-null   int64
#  5    Rate_per_10000_population             2020 non-null   object
#  6    Rate_ratio_NZ_average_rate            2020 non-null   object
#  7   Urban_area_2013_code                   2020 non-null   int64
#  8   Urban_area_2013_label                  2020 non-null   object
#  9   Urban_area_type                        2020 non-null   object
# ...
